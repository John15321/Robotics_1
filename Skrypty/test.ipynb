# %%
import numpy as numpy
import matplotlib.pyplot as plt
import sympy as sp
from sympy import print_latex
from rotations import *

# %%
alpha, beta, gamma, theta = sp.symbols('\\alpha \\beta \\gamma \\theta', real=True)
q1, q2, l1, l2, t = sp.symbols('q1 q2 l1 l2 t', real=True)

# %%
rot_z_fun(alpha)*rot_x_fun(beta)*rot_y_fun(gamma)
# Out:
# Matrix([
# [-sin(\alpha)*sin(\beta)*sin(\gamma) + cos(\alpha)*cos(\gamma), -sin(\alpha)*cos(\beta), sin(\alpha)*sin(\beta)*cos(\gamma) + sin(\gamma)*cos(\alpha)],
# [ sin(\alpha)*cos(\gamma) + sin(\beta)*sin(\gamma)*cos(\alpha),  cos(\alpha)*cos(\beta), sin(\alpha)*sin(\gamma) - sin(\beta)*cos(\alpha)*cos(\gamma)],
# [                                      -sin(\gamma)*cos(\beta),              sin(\beta),                                       cos(\beta)*cos(\gamma)]])

# %%
R = sp.Matrix([
    [ sp.cos(q1 + q2),  -sp.sin(q1 + q2), 0],
    [-sp.sin(q1 + q2),   sp.cos(q1 + q2), 0],
    [               0,                 0, 1]
])
print_latex(R)
# Out:
# \left[\begin{matrix}\cos{\left(q_{1} + q_{2} \right)} & - \sin{\left(q_{1} + q_{2} \right)} & 0\\- \sin{\left(q_{1} + q_{2} \right)} & \cos{\left(q_{1} + q_{2} \right)} & 0\\0 & 0 & 1\end{matrix}\right]

# %%
sp.diff(R, t)
# Out:
# Matrix([
# [0, 0, 0],
# [0, 0, 0],
# [0, 0, 0]])

# %% [markdown]
# $$
#     \left[
#         \begin{matrix}
#             - \dot q_{2} \sin{\left(q_{1} + q_{2} \right)}   & - \dot q_{2} \cos{\left(q_{1} + q_{2} \right)} & 0 \\
#             \dot q _{2} \cos{\left(q_{1} + q_{2} \right)} & - \dot q_{2} \sin{\left(q_{1} + q_{2} \right)}   & 0 \\
#             0                                   & 0                                   & 1
#         \end{matrix}
#         \right]
# $$
